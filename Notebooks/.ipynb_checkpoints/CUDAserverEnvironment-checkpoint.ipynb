# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('../SourceCode')
import bastien_utils
from shallowAE import ShallowAE
from sparseShallowAE import SparseShallowAE_KL, SparseShallowAE_L1, SparseShallowAE_KL_sum
import datetime
# Out:
# Using TensorFlow backend.

# %%
FILE_PATH = "../"
data = bastien_utils.load_data(FILE_PATH, train=True, test=True, subsetTest=True)
x_train, y_train, x_test, y_test, x_small, y_small = data
print('x_small shape:', x_small.shape)
print('x_test shape:', x_test.shape)
# Out:
# ('x_small shape:', (10, 28, 28, 1))
# ('x_test shape:', (10000, 28, 28, 1))

# %%
AE_sparse = SparseShallowAE_KL_sum.load('18_07_11_dim100_KLdivSum_1.0_0.2.h5')

# %%
AE_sparse.reconstruction_error(x_test)
# Out:
# 194.98066630859375

# %%
AE_sparse.plot_reconstructions(x_small)

# %%
X_rec_test = AE_sparse.reconstruction(x_test)

# %%
np.mean((X_rec_test - x_test)**2)
# Out:
# 0.00841751

# %%
H_test = AE_sparse.encode(x_test)

# %%
plt.hist(H_test[:,12])
plt.show()

# %% [markdown]
# ### rho = 0.1, lam = 0.01

# %%
AE_sparse = SparseShallowAE_KL_sum.load('18_07_10_dim100_KLdivSum_0.01_0.1.h5')

# %%
AE_sparse.reconstruction_error(x_test)
# Out:
# 1.8918711711883545

# %%
AE_sparse.reconstruction_error(x_train)
# Out:
# 1.8906884143829346

# %%
AE_sparse.plot_reconstructions(x_small)

# %%
X_rec_test = AE_sparse.reconstruction(x_test)

# %%
np.mean((X_rec_test - x_test)**2)
# Out:
# 0.008454698

# %%
H_test = AE_sparse.encode(x_test)

# %%
plt.hist(H_test.flatten())
plt.show()

# %% [markdown]
# ### sparsity_obejctive = 0.01, sparsity_weight = 1

# %%
AE_sparse = SparseShallowAE_KL_sum.load('18_07_10_dim100_KLdivSum_0.01_0.2.h5')

# %%
H_test = AE_sparse.encode(x_test)

# %%
plt.hist(H_test.flatten())
plt.show()

# %%
AE_sparse.plot_reconstructions(x_small)

# %%
AE_sparse.get_parameters_value()
# Out:
# {'sparsity_objective': 0.20000000298023224,
#  'sparsity_weight': 0.009999999776482582}

# %% [markdown]
# ### Sparsity weight = 1, Sparsity objective= 0.01

# %%
AE_sparse = SparseShallowAE_KL_sum(sparsity_objective=0.01, sparsity_weight=1)

# %%
AE_sparse.train(x_train, nb_epochs=200, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 7s - loss: 264.8853 - val_loss: 265.6968
# Epoch 2/200
# 60000/60000 [==============================] - 7s - loss: 264.8830 - val_loss: 265.6863
# Epoch 3/200
# 60000/60000 [==============================] - 7s - loss: 264.8502 - val_loss: 265.6807
# Epoch 4/200
# 60000/60000 [==============================] - 8s - loss: 264.8773 - val_loss: 265.6766
# Epoch 5/200
# 60000/60000 [==============================] - 7s - loss: 264.8752 - val_loss: 265.6738
# Epoch 6/200
# 60000/60000 [==============================] - 6s - loss: 264.8559 - val_loss: 265.6718
# Epoch 7/200
# 60000/60000 [==============================] - 6s - loss: 264.8328 - val_loss: 265.6705
# Epoch 8/200
# 60000/60000 [==============================] - 6s - loss: 264.8381 - val_loss: 265.6694
# Epoch 9/200
# 60000/60000 [==============================] - 6s - loss: 264.7860 - val_loss: 265.6685
# ...

# %%
AE_sparse.plot_reconstructions(x_small)

# %%
H = AE_sparse.encode(x_test)

# %%
s_hat = np.mean(H, axis=0)

# %%
s_hat.shape
# Out:
# (100,)

# %%
s_hat += 0.00001

# %%
s_hat.shape
# Out:
# (100,)

# %%
rho = 0.01
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))

# %%
val.shape
# Out:
# (100,)

# %%
beta = 1
beta*np.sum(val)
# Out:
# 64.17808532714844

# %%
AE_sparse.reconstruction_error(x_test)
# Out:
# 269.63705783691404

# %%
x_rec_test = AE_sparse.reconstruction(x_test)

# %%
np.mean((X_rec_test - x_test)**2) + beta*np.sum(val)
# Out:
# 64.18652339000255

# %% [markdown]
# ### Test Simple

# %%
AE_simple = ShallowAE()

# %%
AE_simple.train(x_train, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#   256/60000 [..............................] - ETA: 1114s - loss: 0.1796
# /home/bastien/.conda/envs/cudaCMM/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.104625). Check your callbacks.
#   % delta_t_median)
# 60000/60000 [==============================] - 108s - loss: 0.0755 - val_loss: 0.0532
# Epoch 2/100
# 60000/60000 [==============================] - 7s - loss: 0.0477 - val_loss: 0.0433
# Epoch 3/100
# 60000/60000 [==============================] - 7s - loss: 0.0404 - val_loss: 0.0376
# Epoch 4/100
# 60000/60000 [==============================] - 7s - loss: 0.0356 - val_loss: 0.0336
# Epoch 5/100
# 60000/60000 [==============================] - 7s - loss: 0.0322 - val_loss: 0.0308
# Epoch 6/100
# 60000/60000 [==============================] - 7s - loss: 0.0298 - val_loss: 0.0287
# Epoch 7/100
# ...

# %%
recerr = AE_simple.reconstruction_error(x_test)
# Out:
# 0.0107684525385499

# %%
x_rec_test = AE_simple.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)

# %%
mse
# Out:
# 0.010768448

# %% [markdown]
# # 2. Sparse L1

# %%
AE_sparse_L1 = SparseShallowAE_L1(sparsity_weight=0.1)
# Out:
# WARNING:tensorflow:From /home/bastien/.conda/envs/cudaCMM/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1210: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/bastien/.conda/envs/cudaCMM/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1192: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/bastien/.conda/envs/cudaCMM/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1299: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
AE_sparse_L1.train(x_train, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 56576/60000 [===========================>..] - ETA: 0s - loss: 22.5189 - mean_squared_error: 0.0768
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0999e93f4fca> in <module>()
# ----> 1 AE_sparse_L1.train(x_train, X_val=x_test)
#
# /home/bastien/Documents/StageCMM/Mathematical_Morphologies_And_Deep_Learning/SourceCode/shallowAE.pyc in train(self, X_train, nb_epochs, X_val, verbose)
#      62                 batch_size=128,
#      63                 shuffle=True,
# ---> 64                 validation_data=validation_data)
#      65
#      66     def get_encoder(self):
#
# ...

# %%
recerr = AE_sparse_L1.reconstruction_error(x_test)

# %%
x_rec_test = AE_sparse_L1.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)

# %%
mse
# Out:
# 0.010734749

# %%
recerr
# Out:
# 719.2080463867187

# %%
batchSize=254
H_test = AE_sparse_L1.encode(x_test)
l1 = np.mean(np.concatenate(([np.sum(0.1*np.abs(H_test[i*batchSize:(i+1)*batchSize])) for i in range(10000/batchSize)], [np.sum(0.1*np.abs(H_test[int(10000/batchSize)*batchSize:]))])))

# %%
H_test = AE_sparse_L1.encode(x_test)
l1 = np.mean(np.sum(0.1*np.abs(H_test), axis=1))

# %%
l1
# Out:
# 5.0467606

# %%
np.sum(H_test, axis=1).shape
# Out:
# (10000,)

# %%
l1
# Out:
# 1261.6901

# %%
l1 + mse
# Out:
# 1261.7008

# %%
AE_sparse_L1.plot_reconstructions(x_small)

# %% [markdown]
# # 3. Debugging with mse metrics

# %% [markdown]
# ## 3.1 L1 sparse

# %%
AE_sparse_L1 = SparseShallowAE_L1(sparsity_weight=0.1)
# Out:
# WARNING:tensorflow:From /home/bastien/.conda/envs/cudaCMM/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1210: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/bastien/.conda/envs/cudaCMM/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1192: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/bastien/.conda/envs/cudaCMM/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1299: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
AE_sparse_L1.train(x_train, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 8s - loss: 2869.4702 - mean_squared_error: 0.0763 - val_loss: 2875.4919 - val_mean_squared_error: 0.0534
# Epoch 2/100
# 60000/60000 [==============================] - 7s - loss: 2869.3222 - mean_squared_error: 0.0480 - val_loss: 2875.4821 - val_mean_squared_error: 0.0436
# Epoch 3/100
# 60000/60000 [==============================] - 7s - loss: 2869.3921 - mean_squared_error: 0.0407 - val_loss: 2875.4763 - val_mean_squared_error: 0.0378
# Epoch 4/100
# 60000/60000 [==============================] - 6s - loss: 2869.4010 - mean_squared_error: 0.0358 - val_loss: 2875.4722 - val_mean_squared_error: 0.0337
# Epoch 5/100
# 60000/60000 [==============================] - 10s - loss: 2869.3651 - mean_squared_error: 0.0322 - val_loss: 2875.4693 - val_mean_squared_error: 0.0308
# Epoch 6/100
# ...

# %%
recerr = AE_sparse_L1.reconstruction_error(x_test)
recerr
# Out:
# [719.2080983886718, 0.010787275268137456]

# %%
x_rec_test = AE_sparse_L1.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)
mse
# Out:
# 0.010787282

# %%
batchSize=32
H_test = AE_sparse_L1.encode(x_test)
l1 = np.mean(np.sum(0.1*np.abs(H_test), axis=0)) 
l1+recerr[1]
# Out:
# 508.65843131823686

# %% [markdown]
# ## 3.2 Changing the batch size (from 128 to 32)

# %%
AE_sparse_L1 = SparseShallowAE_L1(sparsity_weight=0.1)

# %%
AE_sparse_L1.autoencoder.fit(x=x_train, y=x_train, validation_data=(x_test, x_test), batch_size=32, epochs=100)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 29s - loss: 717.6693 - mean_squared_error: 0.0505 - val_loss: 719.2315 - val_mean_squared_error: 0.0342
# Epoch 2/100
# 60000/60000 [==============================] - 29s - loss: 717.6483 - mean_squared_error: 0.0295 - val_loss: 719.2237 - val_mean_squared_error: 0.0264
# Epoch 3/100
# 60000/60000 [==============================] - 27s - loss: 717.6435 - mean_squared_error: 0.0247 - val_loss: 719.2207 - val_mean_squared_error: 0.0234
# Epoch 4/100
# 60000/60000 [==============================] - 27s - loss: 717.6411 - mean_squared_error: 0.0223 - val_loss: 719.2187 - val_mean_squared_error: 0.0214
# Epoch 5/100
# 60000/60000 [==============================] - 27s - loss: 717.6394 - mean_squared_error: 0.0206 - val_loss: 719.2173 - val_mean_squared_error: 0.0200
# Epoch 6/100
# ...

# %%
recerr = AE_sparse_L1.reconstruction_error(x_test)
recerr
# Out:
# [719.2044788085938, 0.007166816772520542]

# %%
x_rec_test = AE_sparse_L1.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)
mse
# Out:
# 0.007166816

# %% [markdown]
# ## 3.3 New L1

# %%
AE_sparse_L1 = SparseShallowAE_L1(sparsity_weight=0.1)

# %%
AE_sparse_L1.train(x_train, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 8s - loss: 22.5019 - mean_squared_error: 0.0763 - val_loss: 22.5430 - val_mean_squared_error: 0.0540
# Epoch 2/100
# 60000/60000 [==============================] - 8s - loss: 22.4740 - mean_squared_error: 0.0484 - val_loss: 22.5330 - val_mean_squared_error: 0.0440
# Epoch 3/100
# 60000/60000 [==============================] - 8s - loss: 22.4667 - mean_squared_error: 0.0411 - val_loss: 22.5271 - val_mean_squared_error: 0.0381
# Epoch 4/100
# 60000/60000 [==============================] - 8s - loss: 22.4615 - mean_squared_error: 0.0359 - val_loss: 22.5227 - val_mean_squared_error: 0.0337
# Epoch 5/100
# 60000/60000 [==============================] - 8s - loss: 22.4578 - mean_squared_error: 0.0322 - val_loss: 22.5197 - val_mean_squared_error: 0.0307
# Epoch 6/100
# ...

# %%
recerr = AE_sparse_L1.reconstruction_error(x_test)
recerr
# Out:
# [22.499747885131836, 0.010761056791245937]

# %%
x_rec_test = AE_sparse_L1.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)
mse
# Out:
# 0.010761103

# %%
batch_size = 128
beta=0.1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = AE_sparse_L1.encode(x_test[i*batch_size:(i+1)*batch_size])
    l1 = beta*np.mean(np.sum(np.abs(H_test), axis=1))
    batch_vals[i] = l1
H_test = AE_sparse_L1.encode(x_test[nb_batch*batch_size:])
l1 = beta*np.mean(np.sum(np.abs(H_test), axis=1))
batch_vals[-1] = l1
np.mean(batch_vals)
# Out:
# 5.004861831665039

# %%
100*np.abs(np.mean(batch_vals) + recerr[1] - recerr[0])/recerr[0]
# Out:
# 77.37299647182003

# %%
batch_size = 128
beta=0.1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = x_test[i*batch_size:(i+1)*batch_size].reshape((batch_size, 28*28))
    l1 = beta*np.mean(np.sum(np.abs(H_test), axis=1))
    batch_vals[i] = l1
H_test = x_test[nb_batch*batch_size:].reshape((len(x_test)-nb_batch*batch_size, 28*28))
l1 = beta*np.mean(np.sum(np.abs(H_test), axis=1))
batch_vals[-1] = l1
np.mean(batch_vals)
# Out:
# 22.434712064718898

# %%
100*np.abs(np.mean(batch_vals) + recerr[1] - recerr[0])/recerr[0]
# Out:
# 0.24122387459086664

# %% [markdown]
# ## KL_div_sum

# %% [markdown]
# ### 4.1 sparsity_weight=1, sparsity_objective=0.05

# %%
AE_kl = SparseShallowAE_KL_sum(sparsity_weight=1, sparsity_objective=0.05)

# %%
AE_kl.train(x_train, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 8s - loss: 207.1968 - mean_squared_error: 0.0766 - val_loss: 207.6996 - val_mean_squared_error: 0.0548
# Epoch 2/100
# 60000/60000 [==============================] - 8s - loss: 207.2179 - mean_squared_error: 0.0486 - val_loss: 207.6884 - val_mean_squared_error: 0.0436
# Epoch 3/100
# 60000/60000 [==============================] - 8s - loss: 207.0872 - mean_squared_error: 0.0406 - val_loss: 207.6824 - val_mean_squared_error: 0.0376
# Epoch 4/100
# 60000/60000 [==============================] - 8s - loss: 207.1381 - mean_squared_error: 0.0355 - val_loss: 207.6783 - val_mean_squared_error: 0.0335
# Epoch 5/100
# 60000/60000 [==============================] - 8s - loss: 207.2003 - mean_squared_error: 0.0321 - val_loss: 207.6754 - val_mean_squared_error: 0.0306
# Epoch 6/100
# ...

# %%
recerr = AE_kl.reconstruction_error(x_test)
recerr
# Out:
# [207.65556511230469, 0.010784082266688347]

# %%
x_rec_test = AE_kl.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)
mse
# Out:
# 0.010784122

# %%
from keras import backend as K


rho = 0.05
beta=1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = AE_kl.encode(x_test[i*batch_size:(i+1)*batch_size])
    s_hat = np.mean(H_test, axis=0)
    s_hat = np.clip(s_hat,K.epsilon(), 1)
    val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
    batch_vals[i] = beta*np.sum(val)
H_test = AE_kl.encode(x_test[nb_batch*batch_size:])
s_hat = np.mean(H_test, axis=0)
s_hat = np.clip(s_hat,K.epsilon(), 1)
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
batch_vals[-1] = beta*np.sum(val)

# %%
np.mean(batch_vals)
# Out:
# 50.93581887740123

# %%
batch_size=128
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    beta = K.cast_to_floatx(1)
    rho = K.cast_to_floatx(0.05)
    H = K.constant(AE_kl.encode(x_test[i*batch_size:(i+1)*batch_size]))
    s_hat = K.mean(H, 0)
    s_hat = K.clip(s_hat,K.epsilon(), 1)
    val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
    res = beta*K.sum(val)
    tf_session = K.get_session()
    batch_vals[i] = res.eval(session=tf_session)
beta = K.cast_to_floatx(1)
rho = K.cast_to_floatx(0.05)
H = K.constant(AE_kl.encode(x_test[nb_batch*batch_size:]))
s_hat = K.mean(H, 0)
s_hat = K.clip(s_hat,K.epsilon(), 1)
val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
res = beta*K.sum(val)
tf_session = K.get_session()
batch_vals[-1] = res.eval(session=tf_session)

# %%
np.mean(batch_vals)
# Out:
# 51.15999265260334

# %%
100*(51.15999265260334 - 50.93581887740123)/50.93581887740123
# Out:
# 0.44011028023654764

# %%
beta = K.cast_to_floatx(1)
rho = K.cast_to_floatx(0.05)
H = K.constant(AE_kl.encoder.get_weights()[0])
s_hat = K.mean(H, 0)
s_hat = K.clip(s_hat,K.epsilon(), 1)
val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
res = beta*K.sum(val)
tf_session = K.get_session()
res.eval(session=tf_session)
# Out:
# 34.352303

# %%
recerr[0]/(recerr[1]+np.mean(batch_vals))
# Out:
# 4.058088978954252

# %%
AE_kl.plot_reconstructions(x_small)

# %% [markdown]
# ### 4.2 sparsity_weight=10, sparsity_objective=0.05

# %%
AE_kl = SparseShallowAE_KL_sum(sparsity_weight=10, sparsity_objective=0.05)

# %%
AE_kl.train(x_train, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 9s - loss: 2072.0726 - mean_squared_error: 0.0751 - val_loss: 2076.5010 - val_mean_squared_error: 0.0532
# Epoch 2/100
# 60000/60000 [==============================] - 7s - loss: 2070.0351 - mean_squared_error: 0.0477 - val_loss: 2076.4911 - val_mean_squared_error: 0.0433
# Epoch 3/100
# 60000/60000 [==============================] - 7s - loss: 2070.3323 - mean_squared_error: 0.0405 - val_loss: 2076.4854 - val_mean_squared_error: 0.0376
# Epoch 4/100
# 60000/60000 [==============================] - 8s - loss: 2071.6839 - mean_squared_error: 0.0356 - val_loss: 2076.4813 - val_mean_squared_error: 0.0335
# Epoch 5/100
# 60000/60000 [==============================] - 8s - loss: 2071.2863 - mean_squared_error: 0.0321 - val_loss: 2076.4785 - val_mean_squared_error: 0.0307
# Epoch 6/100
# ...

# %%
recerr = AE_kl.reconstruction_error(x_test)
recerr
# Out:
# [2076.4585486328124, 0.010743306183815002]

# %%
x_rec_test = AE_kl.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)
mse
# Out:
# 0.010743347

# %%
from keras import backend as K


rho = 0.05
beta=10
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = AE_kl.encode(x_test[i*batch_size:(i+1)*batch_size])
    s_hat = np.mean(H_test, axis=0)
    s_hat = np.clip(s_hat,K.epsilon(), 1)
    val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
    batch_vals[i] = beta*np.sum(val)
H_test = AE_kl.encode(x_test[nb_batch*batch_size:])
s_hat = np.mean(H_test, axis=0)
s_hat = np.clip(s_hat,K.epsilon(), 1)
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
batch_vals[-1] = beta*np.sum(val)

# %%
np.mean(batch_vals)
# Out:
# 506.0429396810411

# %%
batch_size=128
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    beta = K.cast_to_floatx(10)
    rho = K.cast_to_floatx(0.05)
    H = K.variable(AE_kl.encode(x_test[i*batch_size:(i+1)*batch_size]))
    s_hat = K.mean(H, 0)
    s_hat = K.clip(s_hat,K.epsilon(), 1)
    val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
    res = beta*K.sum(val)
    tf_session = K.get_session()
    batch_vals[i] = res.eval(session=tf_session)
beta = K.cast_to_floatx(10)
rho = K.cast_to_floatx(0.05)
H = K.constant(AE_kl.encode(x_test[nb_batch*batch_size:]))
s_hat = K.mean(H, 0)
s_hat = K.clip(s_hat,K.epsilon(), 1)
val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
res = beta*K.sum(val)
tf_session = K.get_session()
batch_vals[-1] = res.eval(session=tf_session)

# %%
np.mean(batch_vals)
# Out:
# 506.0429401639142

# %%
A = np.dot(x_test.reshape(10000, 784), AE_kl.encoder.get_weights()[0]) + AE_kl.encoder.get_weights()[1]

# %%
from keras import backend as K


rho = 0.05
beta=10
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = x_test[i*batch_size:(i+1)*batch_size]
    s_hat = np.mean(H_test, axis=0)
    s_hat = np.clip(s_hat,K.epsilon(), 1)
    val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
    batch_vals[i] = beta*np.sum(val)
H_test = x_test[nb_batch*batch_size:]
s_hat = np.mean(H_test, axis=0)
s_hat = np.clip(s_hat,K.epsilon(), 1)
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
batch_vals[-1] = beta*np.sum(val)

# %%
100*(recerr[0]-np.mean(batch_vals)+recerr[1])/recerr[0]
# Out:
# 0.1916939000818752

# %%
beta = K.cast_to_floatx(10)
rho = K.cast_to_floatx(0.05)
H = K.variable(AE_kl.encoder.get_weights()[0])
s_hat = K.mean(H, 0)
s_hat = K.clip(s_hat,K.epsilon(), 1)
val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
res = beta*K.sum(val)
tf_session = K.get_session()
res.eval(session=tf_session)
# Out:
# 348.03284

# %%
recerr[0]/(recerr[1]+np.mean(batch_vals))
# Out:
# 4.103237692875142

# %%
AE_kl.plot_reconstructions(x_small)

# %% [markdown]
# ### 4.3 sparsity_weight=0.1, sparsity_objective=0.1

# %%
AE_kl = SparseShallowAE_KL_sum(sparsity_weight=0.1, sparsity_objective=0.1)

# %%
AE_kl.train(x_train, X_val=x_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 8s - loss: 17.5357 - mean_squared_error: 0.0769 - val_loss: 17.5426 - val_mean_squared_error: 0.0537
# Epoch 2/100
# 60000/60000 [==============================] - 7s - loss: 17.5090 - mean_squared_error: 0.0479 - val_loss: 17.5324 - val_mean_squared_error: 0.0435
# Epoch 3/100
# 60000/60000 [==============================] - 7s - loss: 17.5100 - mean_squared_error: 0.0406 - val_loss: 17.5266 - val_mean_squared_error: 0.0377
# Epoch 4/100
# 60000/60000 [==============================] - 7s - loss: 17.5008 - mean_squared_error: 0.0356 - val_loss: 17.5224 - val_mean_squared_error: 0.0335
# Epoch 5/100
# 60000/60000 [==============================] - 7s - loss: 17.4865 - mean_squared_error: 0.0321 - val_loss: 17.5196 - val_mean_squared_error: 0.0307
# Epoch 6/100
# ...

# %%
recerr = AE_kl.reconstruction_error(x_test)
recerr
# Out:
# [17.499694567871092, 0.010768180191516876]

# %%
x_rec_test = AE_kl.reconstruction(x_test)
mse = np.mean((x_rec_test - x_test)**2)
mse
# Out:
# 0.010768232

# %%
from keras import backend as K


rho = 0.1
beta=0.1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = AE_kl.encode(x_test[i*batch_size:(i+1)*batch_size])
    s_hat = np.mean(H_test, axis=0)
    s_hat = np.clip(s_hat,K.epsilon(), 1)
    val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
    batch_vals[i] = beta*np.sum(val)
H_test = AE_kl.encode(x_test[nb_batch*batch_size:])
s_hat = np.mean(H_test, axis=0)
s_hat = np.clip(s_hat,K.epsilon(), 1)
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
batch_vals[-1] = beta*np.sum(val)

# %%
100*np.abs(recerr[0]-np.mean(batch_vals)+recerr[1])/recerr[0]
# Out:
# 78.48425631123187

# %%
batch_size=128
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    beta = K.cast_to_floatx(0.1)
    rho = K.cast_to_floatx(0.1)
    H = K.variable(AE_kl.encode(x_test[i*batch_size:(i+1)*batch_size]))
    s_hat = K.mean(H, 0)
    s_hat = K.clip(s_hat,K.epsilon(), 1)
    val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
    res = beta*K.sum(val)
    tf_session = K.get_session()
    batch_vals[i] = res.eval(session=tf_session)
beta = K.cast_to_floatx(0.1)
rho = K.cast_to_floatx(0.1)
H = K.constant(AE_kl.encode(x_test[nb_batch*batch_size:]))
s_hat = K.mean(H, 0)
s_hat = K.clip(s_hat,K.epsilon(), 1)
val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
res = beta*K.sum(val)
tf_session = K.get_session()
batch_vals[-1] = res.eval(session=tf_session)

# %%
100*np.abs(recerr[0]-np.mean(batch_vals)+recerr[1])/recerr[0]
# Out:
# 78.48425602495215

# %%
A = np.dot(x_test.reshape(10000, 784), AE_kl.encoder.get_weights()[0]) + AE_kl.encoder.get_weights()[1]

# %%
from keras import backend as K


rho = 0.1
beta=1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = A[i*batch_size:(i+1)*batch_size]
    s_hat = np.mean(H_test, axis=0)
    s_hat = np.clip(s_hat,K.epsilon(), 1)
    val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
    batch_vals[i] = beta*np.sum(val)
H_test = A[nb_batch*batch_size:]
s_hat = np.mean(H_test, axis=0)
s_hat = np.clip(s_hat,K.epsilon(), 1)
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
batch_vals[-1] = beta*np.sum(val)

# %%
100*np.abs(recerr[0]-np.mean(batch_vals)-recerr[1])/recerr[0]
# Out:
# 238.36654249777243

# %%
from keras import backend as K


rho = 0.1
beta=0.1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = x_test[i*batch_size:(i+1)*batch_size]
    s_hat = np.mean(H_test, axis=0)
    s_hat = np.clip(s_hat,K.epsilon(), 1)
    val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
    batch_vals[i] = beta*np.sum(val)
H_test = x_test[nb_batch*batch_size:]
s_hat = np.mean(H_test, axis=0)
s_hat = np.clip(s_hat,K.epsilon(), 1)
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
batch_vals[-1] = beta*np.sum(val)

# %%
100*(recerr[0]-np.mean(batch_vals)-recerr[1])/recerr[0]
# Out:
# -0.03854972732052504

# %%
batch_vals2 = batch_vals

# %%
from keras import backend as K


rho = 0.1
beta=0.1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = x_test[i*batch_size:(i+1)*batch_size].reshape((batch_size, 28*28))
    s_hat = np.mean(H_test, axis=0)
    s_hat = np.clip(s_hat,K.epsilon(), 1)
    val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
    batch_vals[i] = beta*np.sum(val)
H_test = x_test[nb_batch*batch_size:].reshape((len(x_test)-nb_batch*batch_size, 28*28))
s_hat = np.mean(H_test, axis=0)
s_hat = np.clip(s_hat,K.epsilon(), 1)
val = rho*np.log(rho/s_hat) + (1 - rho)*np.log((1-rho)/(1-s_hat))
batch_vals[-1] = beta*np.sum(val)

# %%
100*(recerr[0]-np.mean(batch_vals)-recerr[1])/recerr[0]
# Out:
# -0.03854972732052504

# %%
np.all(batch_vals2==batch_vals)
# Out:
# True

# %%
beta = K.cast_to_floatx(10)
rho = K.cast_to_floatx(0.05)
H = K.variable(AE_kl.encoder.get_weights()[0])
s_hat = K.mean(H, 0)
s_hat = K.clip(s_hat,K.epsilon(), 1)
val = rho*K.log(rho/s_hat) + (1 - rho)*K.log((1-rho)/(1-s_hat))
res = beta*K.sum(val)
tf_session = K.get_session()
res.eval(session=tf_session)
# Out:
# 349.50995

# %%
AE_kl.plot_reconstructions(x_small)

# %%
def sigmoid(x):
    return 1. / (1. + np.exp(-x))

# %%
H_ex = sigmoid(A)

# %%
H_ex.shape
# Out:
# (10000, 100)

# %%
H_th = AE_kl.encode(x_test)

# %%
np.max(H_ex - H_th)
# Out:
# 8.940697e-07

# %%
H_th.shape
# Out:
# (10000, 100)

# %% [markdown]
# ### 4.4 L1

# %%
from keras.models import Model, load_model
from keras.layers import Input, Dense, Flatten, Reshape, LeakyReLU, BatchNormalization, Activation
from keras import losses, regularizers, metrics

# %%
latent_dim = 100
sparsity_weight = 0.1
input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format
x = Flatten()(input_img)
encoded = Dense(latent_dim, activation='sigmoid', 
                activity_regularizer=regularizers.l1(sparsity_weight))(x)
encoder = Model(input_img, encoded, name='encoder')
encoded_img = Input(shape=(latent_dim,))  
x = Dense(28*28*1)(encoded_img)
x = LeakyReLU(alpha=0.1)(x)
decoded = Reshape((28,28,1))(x)
decoder = Model(encoded_img, decoded, name='decoder')
encoded = encoder(input_img)
decoded = decoder(encoded)
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='mean_squared_error', metrics=['mse'])

# %%
autoencoder.fit(x_train, x_train, batch_size=128, epochs=100, validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 9s - loss: 2869.3396 - mean_squared_error: 0.0766 - val_loss: 2875.4919 - val_mean_squared_error: 0.0533
# Epoch 2/100
# 60000/60000 [==============================] - 8s - loss: 2869.4590 - mean_squared_error: 0.0475 - val_loss: 2875.4815 - val_mean_squared_error: 0.0430
# Epoch 3/100
# 60000/60000 [==============================] - 8s - loss: 2869.3470 - mean_squared_error: 0.0402 - val_loss: 2875.4759 - val_mean_squared_error: 0.0374
# Epoch 4/100
# 60000/60000 [==============================] - 8s - loss: 2869.3752 - mean_squared_error: 0.0353 - val_loss: 2875.4719 - val_mean_squared_error: 0.0334
# Epoch 5/100
# 60000/60000 [==============================] - 8s - loss: 2869.3066 - mean_squared_error: 0.0320 - val_loss: 2875.4691 - val_mean_squared_error: 0.0306
# Epoch 6/100
# ...

# %%
recerr = autoencoder.evaluate(x_test, x_test, batch_size=32)
recerr
# Out:
#  9952/10000 [============================>.] - ETA: 0s
# [719.2081229003907, 0.010809235274791718]

# %%
x_rec_test = autoencoder.predict(x_test, batch_size=32)
mse = np.mean((x_rec_test - x_test)**2)
mse
# Out:
# 0.010809246

# %%
batch_size = 32
beta=0.1
nb_batch = int(len(x_test)/batch_size)
batch_vals = np.zeros(nb_batch + 1)
for i in range(nb_batch):
    H_test = x_test[i*batch_size:(i+1)*batch_size].reshape((batch_size, 28*28))
    l1 = np.sum(beta*np.abs(H_test))
    batch_vals[i] = l1
H_test = x_test[-batch_size:].reshape((batch_size, 28*28))
l1 = np.sum(beta*np.abs(H_test))
batch_vals[-1] = l1
np.mean(batch_vals)
# Out:
# 719.7093028108152

# %%
100*np.abs(recerr[0]-np.mean(batch_vals)-recerr[1])/recerr[0]
# Out:
# 0.07118789810584872
