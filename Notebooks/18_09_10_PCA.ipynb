# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('../SourceCode')
import bastien_utils
import morphoMaths
import pandas as pd
from scipy import io
import metrics
# Out:
# Using TensorFlow backend.

# %%
from sklearn.decomposition import PCA

# %%
FILE_PATH = "../"
x_train, _, x_test, y_test = bastien_utils.load_data(FILE_PATH, train=True, test=True, subsetTest=False)
print('x_test shape:', x_test.shape)
x_small = x_test[:10]
x_small[2] = x_test[31]
# Out:
# x_test shape: (10000, 28, 28, 1)

# %%
bastien_utils.plot_all_images(x_small)

# %%
pca = PCA(n_components=100)

# %%
pca.fit(x_train.reshape((60000, 28*28)))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
H_test = pca.transform(x_test.reshape((10000, 28*28)))

# %%
H_small = pca.transform(x_small.reshape((10, 28*28)))

# %%
x_rec_small = pca.inverse_transform(H_small)

# %%
bastien_utils.plot_all_images(x_rec_small.reshape(10,28,28,1))

# %%
pca = PCA(n_components=100)

# %%
pca.fit(x_test.reshape((10000, 28*28)))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
H_small = pca.transform(x_small.reshape((10, 28*28)))

# %%
x_rec_small = pca.inverse_transform(H_small)

# %%
bastien_utils.plot_all_images(x_rec_small.reshape(10,28,28,1))

# %%
    pca

# %%
pca = PCA(n_components=100, whiten=True)

# %%
pca.fit(x_test.reshape((10000, 28*28)))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=True)

# %%
H_small = pca.transform(x_small.reshape((10, 28*28)))

# %%
x_rec_small = pca.inverse_transform(H_small)

# %%
bastien_utils.plot_all_images(x_rec_small.reshape(10,28,28,1))

# %%
pca = PCA(n_components=100, whiten=True)

# %%
pca.fit(x_train.reshape((60000, 28*28)))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=100, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=True)

# %%
H_small = pca.transform(x_small.reshape((10, 28*28)))

# %%
x_rec_small = pca.inverse_transform(H_small)

# %%
bastien_utils.plot_all_images(x_rec_small.reshape(10,28,28,1))

# %%
W = pca.components_

# %%
W.shape
# Out:
# (100, 784)

# %%
bastien_utils.plot_all_images(W.reshape(100, 28,28,1))
