# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('../SourceCode')
import bastien_utils
import datetime
import morphoMaths
import pandas as pd
from scipy import io
import metrics
from MaxPlusDecoder.ShallowAE_maxPlusDecoder.shallowAE_maxplus import ShallowAE_MaxPlus
# Out:
# Using TensorFlow backend.

# %%
#Loading FashionMNIST
FILE_PATH = "../"
x_train, _, x_test, y_test = bastien_utils.load_data_fashionMNIST(FILE_PATH, train=True, test=True, subsetTest=False)
idx_small = np.arange(10)
idx_small[2]=31
x_small = x_test[idx_small]
print('x_small shape:', x_small.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_small shape: (10, 28, 28, 1)
# x_test shape: (10000, 28, 28, 1)

# %%
results = pd.read_csv("../Results/ShallowAE_MaxPlus/Simple/TestOutputs/18_12_03results")
results
# Out:
#    Unnamed: 0  dimension  test_error  \
# 0           0        100    0.040553
#
#    test_max_approx_error_toOriginal_dilatation  \
# 0                                     0.350734
#
#    test_max_approx_error_toRec_dilatation  test_sparsity  training_error  \
# 0                                 0.24508       0.896257        0.040623
#
#    training_max_approx_error_toOriginal_dilatation  \
# 0                                         0.350132
#
#    training_max_approx_error_toRec_dilatation  training_sparsity
# 0                                    0.244292           0.895606

# %%
test_mse = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_test_errors_100_100.npy')
train_mse = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_training_errors_100_100.npy')
test_max_approx_to_Original = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_test_max_approx_error_toOriginal_dilation_100_100.npy')
train_max_approx_to_Original = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_training_max_approx_error_toOriginal_dilatation_100_100.npy')
test_max_approx_to_Rec = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_test_max_approx_error_toRec_dilation_100_100.npy')
train_max_approx_to_Rec = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_training_max_approx_error_toRec_dilatation_100_100.npy')
test_sparsity = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_test_sparsity_100_100.npy')
train_sparsity = np.load('../Results/ShallowAE_MaxPlus/Simple/TestOutputs/Without_dropout/18_12_03_training_sparsity_100_100.npy')

# %%
AE = ShallowAE_MaxPlus.load('Without_dropout/18_12_03_dim100.h5')
print('Original images and reconstructions - Reconstruction error: ', test_mse[0])
AE.plot_reconstructions(x_small)
print('Histograms of the encodings - Sparsity (Hoyer): ', test_sparsity[0])
AE.plot_histograms_of_the_encoding(x_small)
print('Atom images of the decoder')
AE.plot_atoms_decoder(nb_to_plot=100)
AE.plot_histograms_of_the_decoder_atoms()
# Out:
# Original images and reconstructions - Reconstruction error:  0.040553121834993364
# Histograms of the encodings - Sparsity (Hoyer):  0.8962574005126953
# Atom images of the decoder

# %%
x_rec = AE.reconstruction(x_test)
plt.hist(x_rec.flatten())
plt.show()

# %%
print('Dilatation of the original images')
bastien_utils.plot_all_images(bastien_utils.apply_operator_to_all_images(morphoMaths.dilatation, x_small, SE_scale=1))
print('Dilatation of the reconstructions')
bastien_utils.plot_all_images(bastien_utils.apply_operator_to_all_images(morphoMaths.dilatation, AE.reconstruction(x_small), SE_scale=1))
AE_dil = AE.apply_operator_to_decoder_atoms(morphoMaths.dilatation, apply_to_bias=False, SE_scale=1)
print('Original images and max-approximation to dilatation')
print('Max-approx error to original: ', test_max_approx_to_Original[0], ' - Max-approx error to reconstruction: ', test_max_approx_to_Rec[0])
AE_dil.plot_reconstructions(x_small)
print('Dilated of the atom images of the decoder')
AE_dil.plot_atoms_decoder(nb_to_plot=30)
# Out:
# Dilatation of the original images
# Dilatation of the reconstructions
# Original images and max-approximation to dilatation
# Max-approx error to original:  0.35073398566246033  - Max-approx error to reconstruction:  0.24507984881401063
# Dilated of the atom images of the decoder
