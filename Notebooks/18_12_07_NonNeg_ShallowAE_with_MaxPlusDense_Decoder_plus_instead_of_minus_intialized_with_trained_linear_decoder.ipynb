# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('../SourceCode')
import bastien_utils
import datetime
import morphoMaths
import pandas as pd
from scipy import io
import metrics
from MaxPlusDecoder.ShallowAE_maxPlusDecoder.shallowAE_maxplus_NonNeg import NonNeg_ShallowAE_MaxPlus_NonNegConstraint
from nonNegShallowAE import NonNegShallowAE_NonNegConstraint

# %%
#Loading FashionMNIST
FILE_PATH = "../"
x_train, _, x_test, y_test = bastien_utils.load_data_fashionMNIST(FILE_PATH, train=True, test=True, subsetTest=False)
idx_small = np.arange(10)
idx_small[2]=31
x_small = x_test[idx_small]
print('x_small shape:', x_small.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_small shape: (10, 28, 28, 1)
# x_test shape: (10000, 28, 28, 1)

# %%
AE_linear = NonNegShallowAE_NonNegConstraint.load('18_08_13_dim100_NonNegConstraint.h5')

# %%
AE_linear.plot_atoms_decoder()

# %%
w = AE_linear.decoder.get_weights()

# %%
w[0].shape
# Out:
# (100, 784)

# %%
AE_maxplus = NonNeg_ShallowAE_MaxPlus_NonNegConstraint()

# %%
AE_maxplus.plot_atoms_decoder()

# %%
AE_maxplus.decoder.set_weights([w[0]])

# %%
AE_maxplus.encoder.set_weights([AE_linear.encoder.get_weights()[0]])

# %%
AE_maxplus.plot_atoms_encoder()

# %%
AE_maxplus.plot_atoms_decoder()

# %%
AE_linear.plot_reconstructions(x_small)

# %%
AE_maxplus.plot_reconstructions(x_small)

# %%
AE_maxplus.train(x_train, nb_epochs=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 258s 4ms/step - loss: 0.2119 - mean_squared_error: 0.2119

# %%
AE_maxplus.plot_reconstructions(x_small)

# %%
AE_maxplus.plot_atoms_decoder()

# %%
AE_maxplus.train(x_train, nb_epochs=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 260s 4ms/step - loss: 0.1097 - mean_squared_error: 0.1097

# %%
AE_maxplus.plot_reconstructions(x_small)

# %%
AE_maxplus.plot_atoms_decoder()

# %%
AE_maxplus.train(x_train, nb_epochs=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 258s 4ms/step - loss: 0.0957 - mean_squared_error: 0.0957

# %%
AE_maxplus.plot_reconstructions(x_small)

# %%
AE_maxplus.plot_atoms_decoder()

# %%
AE_maxplus.train(x_train, nb_epochs=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 254s 4ms/step - loss: 0.0916 - mean_squared_error: 0.0916

# %%
AE_maxplus.plot_reconstructions(x_small)

# %%
AE_maxplus.plot_atoms_decoder()

# %%
AE_maxplus.train(x_train, nb_epochs=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 253s 4ms/step - loss: 0.0899 - mean_squared_error: 0.0899

# %%
AE_maxplus.plot_reconstructions(x_small)

# %%
AE_maxplus.plot_atoms_decoder()

# %%
AE_maxplus.train(x_train, nb_epochs=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 287s 5ms/step - loss: 0.0890 - mean_squared_error: 0.0890

# %%
AE_maxplus.plot_reconstructions(x_small)

# %%
AE_maxplus.plot_atoms_decoder()
